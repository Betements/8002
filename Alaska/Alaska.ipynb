# %%
# %cd '/home/nbuser/library/DP/Alaska'
from read_in_census_data import CensusInfo, DataFrameWrapper
five_percent_data_file = 'REVISEDPUMS5_02.TXT'
tract_data = 'PUMEQ5-AK.TXT'
data_dictionary = '5%_PUMS_record_layout.xls'
ci = CensusInfo (data_dictionary)
# Out:
# /home/nbuser/library/DP/Alaska
# Processing 'Housing Unit Record' Sheet
#
# Processing 'Person Record' Sheet

# %%
import pandas as pd
import numpy as np

# %% [raw]
# df.fill_frame ([], ci.person_record,
#                    five_percent_data_file,
#                    ci.five_percent_file,
#                'race','education','income','gender','age','relationship')
# df.save_frame('Alaska_Pums_Extract.csv',header=True)
# dt_dict ={'serial_no':object,'race':object,'education':object,
#               'gender':object,'relationship':object}
# p_df = pd.read_csv('Alaska_Pums_Extract.csv', dtype=dt_dict)

# %% [raw]
# u'TENURE': {u'BEG': 113
# Home ownership
# - add A for flag (???)
# u'VALUE Beg 202 - Property Value
# YRBUILT 188 - Yar Building BUilt
# EDUC - educational attainement
# Divide into race and tract number
# YR2US year of entry to US
# RENT -monthly rent
# PUMA1
# PUMA5

# %%
ci.print_var_info('TENURE',ci.record_types[0])
ci.print_var_info('RACE3',ci.record_types[1])
ci.print_var_info('YRBUILT',ci.record_types[0])
ci.print_var_info('VALUE',ci.record_types[0])
ci.print_var_info('DIVISION',ci.record_types[0])

# %%
# ci.print_var_info('TOTPUMA5',ci.record_types[0])
# ci.print_var_info('SUBSAMPL',ci.record_types[0])
ci.print_var_info('VALUE',ci.record_types[0])
# Out:
# Housing Unit Record VALUE 5% file {u'RT': u'H', u'BEG': 202, u'LEN': 2, u'DESCRIPTION': u'Property Value'}
#
#      Property Value
#      ==============
#      01  Less than $10,000
#      02  $10,000 to $14,999
#      03  $15,000 to $19,999
#      04  $20,000 to $24,999
#      05  $25,000 to $29,999
#      06  $30,000 to $34,999
#      07  $35,000 to $39,999
#      08  $40,000 to $49,999
#      09  $50,000 to $59,999
#      10  $60,000 to $69,999
#      11  $70,000 to $79,999
#      12  $80,000 to $89,999
#      13  $90,000 to $99,999
#      14  $100,000 to $124,999
#      15  $125,000 to $149,999
#      16  $150,000 to $174,999
#      17  $175,000 to $199,999
#      18  $200,000 to $249,999
#      19  $250,000 to $299,999
#      20  $300,000 to $399,999
#      21  $400,000 to $499,999
#      22  $500,000 to $749,999
#      23  $750,000 to $999,999
#      24  $1,000,000 or more
#      blank  Not in universe (GQ, TENURE = 3-4, or VACSTAT = 1, 3-6)

# %%
ci.data_dictionary
# Out:
# {u'Housing Unit Record': {u'ACRES': {u'BEG': 138,
#    u'DESCRIPTION': u'Acreage',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'ACRESA': {u'BEG': 139,
#    u'DESCRIPTION': u'Acreage Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'AGSALES': {u'BEG': 140,
#    u'DESCRIPTION': u'Sales of Agricultural Products in 1999',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'AGSALESA': {u'BEG': 141,
#    u'DESCRIPTION': u'Sales of Agricultural Products in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'AREATYP1': {u'BEG': 42,
#    u'DESCRIPTION': u'Metropolitan Area: SuperPUMA Relationship to MA',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'AREATYP5': {u'BEG': 40,
#    u'DESCRIPTION': u'Metropolitan Area: PUMA Relationship to MA',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'BEDRMS': {u'BEG': 124,
#    u'DESCRIPTION': u'Number of Bedrooms',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'BEDRMSA': {u'BEG': 125,
#    u'DESCRIPTION': u'Number of Bedrooms Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'BLDGSZ': {u'BEG': 115,
#    u'DESCRIPTION': u'Size of Building',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'BLDGSZA': {u'BEG': 117,
#    u'DESCRIPTION': u'Size of Building Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H '},
#   u'BUSINES': {u'BEG': 136,
#    u'DESCRIPTION': u'Commercial Business on Property',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'BUSINESA': {u'BEG': 137,
#    u'DESCRIPTION': u'Commercial Business on Property Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'CKITCH': {u'BEG': 128,
#    u'DESCRIPTION': u'Complete Kitchen Facilities',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'CKITCHA': {u'BEG': 129,
#    u'DESCRIPTION': u'Complete Kitchen Facilities Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'CONDFEE': {u'BEG': 197,
#    u'DESCRIPTION': u'Condominium Fee (monthly)',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'CONDFEEA': {u'BEG': 201,
#    u'DESCRIPTION': u'Condominium Fee (monthly) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'CPLUMB': {u'BEG': 126,
#    u'DESCRIPTION': u'Complete Plumbing Facilities',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'CPLUMBA': {u'BEG': 127,
#    u'DESCRIPTION': u'Complete Plumbing Facilities Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'DIVISION': {u'BEG': 13,
#    u'DESCRIPTION': u'Division Code',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'ELEC': {u'BEG': 142,
#    u'DESCRIPTION': u'Cost of Electricity (annual)',
#    u'LEN': 4,
#    u'RT': u'H '},
#   u'ELECA': {u'BEG': 146,
#    u'DESCRIPTION': u'Cost of Electricity (annual) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'EMPSTAT': {u'BEG': 248,
#    u'DESCRIPTION': u'Family Type and Employment Status',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'FINC': {u'BEG': 259,
#    u'DESCRIPTION': u'Family Total Income in 1999',
#    u'LEN': 8,
#    u'RT': u'H'},
#   u'FINC ': {u'BEG': 259,
#    u'DESCRIPTION': u'Family Total Income in 1999',
#    u'LEN': 8,
#    u'RT': u'H'},
#   u'FNF': {u'BEG': 244,
#    u'DESCRIPTION': u'Farm/Nonfarm Recode',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'FUEL': {u'BEG': 132,
#    u'DESCRIPTION': u'Heating Fuel',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'FUELA': {u'BEG': 133,
#    u'DESCRIPTION': u'Heating Fuel Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'GAS ': {u'BEG': 147,
#    u'DESCRIPTION': u'Cost of Gas (annual)',
#    u'LEN': 4,
#    u'RT': u'H '},
#   u'GASA': {u'BEG': 151,
#    u'DESCRIPTION': u'Cost of Gas (annual) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'GRAPI': {u'BEG': 241,
#    u'DESCRIPTION': u'Gross Rent as a Percentage of Household Income',
#    u'LEN': 3,
#    u'RT': u'H'},
#   u'GRENT': {u'BEG': 237,
#    u'DESCRIPTION': u'Gross Rent',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'HAUG': {u'BEG': 110,
#    u'DESCRIPTION': u'Augmentation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'HHL': {u'BEG': 245,
#    u'DESCRIPTION': u'Household Language',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'HHT': {u'BEG': 213,
#    u'DESCRIPTION': u'Household/Family Type',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'HINC': {u'BEG': 251,
#    u'DESCRIPTION': u'Household Total Income in 1999',
#    u'LEN': 8,
#    u'RT': u'H'},
#   u'HINC ': {u'BEG': 251,
#    u'DESCRIPTION': u'Household Total Income in 1999',
#    u'LEN': 8,
#    u'RT': u'H'},
#   u'HSUB': {u'BEG': 109,
#    u'DESCRIPTION': u'Substitution Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'HWEIGHT': {u'BEG': 102,
#    u'DESCRIPTION': u'Housing unit weight',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'INSAMT': {u'BEG': 192,
#    u'DESCRIPTION': u'Property Insurance Amount (annual)',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'INSAMTA': {u'BEG': 196,
#    u'DESCRIPTION': u'Property Insurance Amount (annual) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'INSINCL': {u'BEG': 190,
#    u'DESCRIPTION': u'Property Insurance Status',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'INSINCLA': {u'BEG': 191,
#    u'DESCRIPTION': u'Property Insurance Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'LNDPUMA1': {u'BEG': 86,
#    u'DESCRIPTION': u'Land Area of SuperPUMA',
#    u'LEN': 14,
#    u'RT': u'H'},
#   u'LNDPUMA5': {u'BEG': 58,
#    u'DESCRIPTION': u'Land Area of PUMA',
#    u'LEN': 14,
#    u'RT': u'H'},
#   u'LNGI': {u'BEG': 246,
#    u'DESCRIPTION': u'Linguistic Isolation',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MEALS': {u'BEG': 167,
#    u'DESCRIPTION': u'Meals Included in Rent',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MEALSA': {u'BEG': 168,
#    u'DESCRIPTION': u'Meals Included in Rent Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MHCOST': {u'BEG': 207,
#    u'DESCRIPTION': u'Mobile Home Costs',
#    u'LEN': 5,
#    u'RT': u'H'},
#   u'MHCOSTA': {u'BEG': 212,
#    u'DESCRIPTION': u'Mobile Home Costs Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MHLOAN': {u'BEG': 205,
#    u'DESCRIPTION': u'Mobile Home Loan Status',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MHLOANA': {u'BEG': 206,
#    u'DESCRIPTION': u'Mobile Home Loan Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MORTG1': {u'BEG': 169,
#    u'DESCRIPTION': u'Mortgage Status',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MORTG1A': {u'BEG': 170,
#    u'DESCRIPTION': u'Mortgage Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MORTG2': {u'BEG': 177,
#    u'DESCRIPTION': u'Second Mortgage Status',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MORTG2A': {u'BEG': 178,
#    u'DESCRIPTION': u'Second Mortgage Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MRT1AMT': {u'BEG': 171,
#    u'DESCRIPTION': u'Mortgage Payment (monthly amount)',
#    u'LEN': 5,
#    u'RT': u'H'},
#   u'MRT1AMTA': {u'BEG': 176,
#    u'DESCRIPTION': u'Mortgage Payment (monthly amount) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MRT2AMT': {u'BEG': 179,
#    u'DESCRIPTION': u'Second Mortgage Payment (monthly amount)',
#    u'LEN': 5,
#    u'RT': u'H'},
#   u'MRT2AMTA': {u'BEG': 184,
#    u'DESCRIPTION': u'Second Mortgage Payment (monthly amount) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'MSACMSA1': {u'BEG': 32,
#    u'DESCRIPTION': u'Metropolitan Area: MSA/CMSA for SuperPUMA',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'MSACMSA5': {u'BEG': 24,
#    u'DESCRIPTION': u'Metropolitan Area (MA): MSA/CMSA for PUMA',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'MSAPMSA1': {u'BEG': 36,
#    u'DESCRIPTION': u'Metropolitan Area: MSA/PMSA for SuperPUMA',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'MSAPMSA5': {u'BEG': 28,
#    u'DESCRIPTION': u'Metropolitan Area: MSA/PMSA for PUMA',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'NOC': {u'BEG': 220,
#    u'DESCRIPTION': u'Number of own children under 18 years in household',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'NPF': {u'BEG': 218,
#    u'DESCRIPTION': u'Number of people in family',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'NRC': {u'BEG': 222,
#    u'DESCRIPTION': u'Number of related children under 18 years in household',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'OIL ': {u'BEG': 157,
#    u'DESCRIPTION': u'Cost of Oil, Kerosene, or Wood (annual)',
#    u'LEN': 4,
#    u'RT': u'H'},
#   u'OILA': {u'BEG': 161,
#    u'DESCRIPTION': u'Cost of Oil, Kerosene, or Wood (annual) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'P18': {u'BEG': 216,
#    u'DESCRIPTION': u'Number of people under 18 years in household',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'P65': {u'BEG': 214,
#    u'DESCRIPTION': u'Number of people 65 years and over in household',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'PAOC': {u'BEG': 225,
#    u'DESCRIPTION': u'Presence and Age of Own Children under 18 years',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'PARC': {u'BEG': 226,
#    u'DESCRIPTION': u'Presence and Age of Related Children under 18 years',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'PERSONS': {u'BEG': 106,
#    u'DESCRIPTION': u'Number of person records following this housing record',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'PHONE': {u'BEG': 130,
#    u'DESCRIPTION': u'Telephone Availability',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'PHONEA': {u'BEG': 131,
#    u'DESCRIPTION': u'Telephone Availability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'PSF': {u'BEG': 224,
#    u'DESCRIPTION': u'Presence of Subfamily in Household',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'PUMA1': {u'BEG': 19,
#    u'DESCRIPTION': u'Super Public Use Microdata Area Code (SuperPUMA)',
#    u'LEN': 5,
#    u'RT': u'H '},
#   u'PUMA5': {u'BEG': 14,
#    u'DESCRIPTION': u'Public Use Microdata Area Code (PUMA)',
#    u'LEN': 5,
#    u'RT': u'H'},
#   u'RECTYPE': {u'BEG': 1,
#    u'DESCRIPTION': u'Record Type',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'REGION': {u'BEG': 12,
#    u'DESCRIPTION': u'Region  Code',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'RENT ': {u'BEG': 162,
#    u'DESCRIPTION': u'Monthly Rent',
#    u'LEN': 4,
#    u'RT': u'H '},
#   u'RENTA': {u'BEG': 166,
#    u'DESCRIPTION': u'Monthly Rent Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'ROOMS': {u'BEG': 122,
#    u'DESCRIPTION': u'Number of Rooms',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'ROOMSA': {u'BEG': 123,
#    u'DESCRIPTION': u'Number of Rooms Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'SAMPLE': {u'BEG': 9,
#    u'DESCRIPTION': u'Sample Identifier',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'SERIALNO': {u'BEG': 2,
#    u'DESCRIPTION': u'Housing/Group Quarters (GQ) Unit Serial Number',
#    u'LEN': 7,
#    u'RT': u'H'},
#   u'SMOC': {u'BEG': 228,
#    u'DESCRIPTION': u'Selected Monthly Owner Costs',
#    u'LEN': 5,
#    u'RT': u'H'},
#   u'SMOC ': {u'BEG': 228,
#    u'DESCRIPTION': u'Selected Monthly Owner Costs',
#    u'LEN': 5,
#    u'RT': u'H'},
#   u'SMOCAPI': {u'BEG': 233,
#    u'DESCRIPTION': u'Selected Monthly Owner Costs as a Percentage of Household Income',
#    u'LEN': 3,
#    u'RT': u'H '},
#   u'SRNT': {u'BEG': 236,
#    u'DESCRIPTION': u'Specified Rent Indicator',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'STATE': {u'BEG': 10,
#    u'DESCRIPTION': u'State Code',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'SUBSAMPL': {u'BEG': 100,
#    u'DESCRIPTION': u'Subsample number',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'SVAL': {u'BEG': 227,
#    u'DESCRIPTION': u'Specified Value Indicator',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'TAXAMT': {u'BEG': 187,
#    u'DESCRIPTION': u'Property Tax Amount (annual)',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'TAXAMTA': {u'BEG': 189,
#    u'DESCRIPTION': u'Property Tax Amount (annual) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'TAXINCL': {u'BEG': 185,
#    u'DESCRIPTION': u'Property Tax Status',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'TAXINCLA': {u'BEG': 186,
#    u'DESCRIPTION': u'Property Tax Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H '},
#   u'TENURE': {u'BEG': 113,
#    u'DESCRIPTION': u'Home Ownership',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'TENUREA': {u'BEG': 114,
#    u'DESCRIPTION': u'Home Ownership Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'TOTPUMA1': {u'BEG': 72,
#    u'DESCRIPTION': u'Total Area of SuperPUMA',
#    u'LEN': 14,
#    u'RT': u'H'},
#   u'TOTPUMA5': {u'BEG': 44,
#    u'DESCRIPTION': u'Total Area of PUMA',
#    u'LEN': 14,
#    u'RT': u'H'},
#   u'UNITTYPE': {u'BEG': 108,
#    u'DESCRIPTION': u'Type of unit',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'VACSTAT': {u'BEG': 111,
#    u'DESCRIPTION': u'Vacancy Status',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'VACSTATA': {u'BEG': 112,
#    u'DESCRIPTION': u'Vacancy Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'VALUE': {u'BEG': 202,
#    u'DESCRIPTION': u'Property Value',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'VALUEA': {u'BEG': 204,
#    u'DESCRIPTION': u'Property Value Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'VEHICL': {u'BEG': 134,
#    u'DESCRIPTION': u'Number of Vehicles Available',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'VEHICLA': {u'BEG': 135,
#    u'DESCRIPTION': u'Number of Vehicles Available Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'WATER ': {u'BEG': 152,
#    u'DESCRIPTION': u'Cost of Water and Sewer (annual)',
#    u'LEN': 4,
#    u'RT': u'H '},
#   u'WATERA': {u'BEG': 156,
#    u'DESCRIPTION': u'Cost of Water and Sewer (annual) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'WIF': {u'BEG': 247,
#    u'DESCRIPTION': u'Number of workers in family',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'WORKEXP': {u'BEG': 249,
#    u'DESCRIPTION': u'Family Type and Work Experience of Householder',
#    u'LEN': 2,
#    u'RT': u'H'},
#   u'YRBUILT': {u'BEG': 118,
#    u'DESCRIPTION': u'Year Building Built',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'YRBUILTA': {u'BEG': 119,
#    u'DESCRIPTION': u'Year Building Built Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'YRMOVED': {u'BEG': 120,
#    u'DESCRIPTION': u'Year Moved In',
#    u'LEN': 1,
#    u'RT': u'H'},
#   u'YRMOVEDA': {u'BEG': 121,
#    u'DESCRIPTION': u'Year Moved In Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'H'}},
#  u'Person Record': {u'ABGO': {u'BEG': 127,
#    u'DESCRIPTION': u'Able to Go Out Disability',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ABGOA': {u'BEG': 128,
#    u'DESCRIPTION': u'Able to Go Out Disability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ABSENT': {u'BEG': 205,
#    u'DESCRIPTION': u'Absent from Work',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ABWORK': {u'BEG': 129,
#    u'DESCRIPTION': u'Employment Disability',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ABWORKA': {u'BEG': 130,
#    u'DESCRIPTION': u'Employment Disability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'AGE ': {u'BEG': 25, u'DESCRIPTION': u'Age', u'LEN': 2, u'RT': u'P'},
#   u'AGEA': {u'BEG': 27,
#    u'DESCRIPTION': u'Age Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'AIAN': {u'BEG': 34,
#    u'DESCRIPTION': u'American Indian and Alaska Native recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ANCA': {u'BEG': 62,
#    u'DESCRIPTION': u'Ancestry Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ANCFRST1': {u'BEG': 56,
#    u'DESCRIPTION': u'Ancestry Code 1 for 1% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'ANCFRST5': {u'BEG': 56,
#    u'DESCRIPTION': u'Ancestry Code 1 for 5% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'ANCR': {u'BEG': 63,
#    u'DESCRIPTION': u'Ancestry Recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ANCSCND1': {u'BEG': 59,
#    u'DESCRIPTION': u'Ancestry Code 2 for 1% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'ANCSCND5': {u'BEG': 59,
#    u'DESCRIPTION': u'Ancestry Code 2 for 5% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'ASIAN': {u'BEG': 35,
#    u'DESCRIPTION': u'Asian recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'BACKWRK': {u'BEG': 208,
#    u'DESCRIPTION': u'Back to Work',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'BLACK': {u'BEG': 33,
#    u'DESCRIPTION': u'Black or African American recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'CARPOOL': {u'BEG': 194,
#    u'DESCRIPTION': u'Vehicle Occupancy',
#    u'LEN': 1,
#    u'RT': u'P '},
#   u'CARPOOLA': {u'BEG': 195,
#    u'DESCRIPTION': u'Vehicle Occupancy Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'CITIZEN': {u'BEG': 76,
#    u'DESCRIPTION': u'Citizenship Status ',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'CITIZENA': {u'BEG': 77,
#    u'DESCRIPTION': u'Citizenship Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'CLWKR': {u'BEG': 234,
#    u'DESCRIPTION': u'Class of Worker',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'CLWKRA': {u'BEG': 235,
#    u'DESCRIPTION': u'Class of Worker Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'DDP': {u'BEG': 12,
#    u'DESCRIPTION': u'Data-defined Person Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'DISABLE': {u'BEG': 131,
#    u'DESCRIPTION': u'Disability Recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'EARNS': {u'BEG': 305,
#    u'DESCRIPTION': u"Person's Total Earnings in 1999",
#    u'LEN': 7,
#    u'RT': u'P'},
#   u'EDUC': {u'BEG': 53,
#    u'DESCRIPTION': u'Educational Attainment',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'EDUCA': {u'BEG': 55,
#    u'DESCRIPTION': u'Educational Attainment Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ENGABIL': {u'BEG': 70,
#    u'DESCRIPTION': u'English Ability ',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ENGABILA': {u'BEG': 71,
#    u'DESCRIPTION': u'English Ability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ENROLL': {u'BEG': 49,
#    u'DESCRIPTION': u'School Enrollment; Attended since February 1, 2000',
#    u'LEN': 1,
#    u'RT': u'P '},
#   u'ENROLLA': {u'BEG': 50,
#    u'DESCRIPTION': u'School Enrollment: Attended since February 1, 2000 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ESP': {u'BEG': 156,
#    u'DESCRIPTION': u'Employment Status of Parent(s)',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ESR': {u'BEG': 154,
#    u'DESCRIPTION': u'Employment Status Recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'ESRA': {u'BEG': 155,
#    u'DESCRIPTION': u'Employment Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'FILLER': {u'BEG': 315, u'DESCRIPTION': '', u'LEN': 2, u'RT': u'P'},
#   u'GRADE': {u'BEG': 51,
#    u'DESCRIPTION': u'School Enrollment: Grade Level Attending',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'GRADEA': {u'BEG': 52,
#    u'DESCRIPTION': u'School Enrollment: Grade Level Attending Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'GRANDC': {u'BEG': 132,
#    u'DESCRIPTION': u'Presence of Grandchildren under 18 years',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'GRANDCA': {u'BEG': 133,
#    u'DESCRIPTION': u'Presence of Grandchildren under 18 years Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'HISPAN': {u'BEG': 28,
#    u'DESCRIPTION': u'Hispanic or Latino Origin',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'HISPANA': {u'BEG': 30,
#    u'DESCRIPTION': u'Hispanic or Latino Origin Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'HOURS': {u'BEG': 241,
#    u'DESCRIPTION': u'Hours per Week in 1999',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'HOURSA': {u'BEG': 243,
#    u'DESCRIPTION': u'Hours per Week in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'HOWLONG': {u'BEG': 136,
#    u'DESCRIPTION': u'Length of Responsibility for Grandchildren',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'HOWLONGA': {u'BEG': 137,
#    u'DESCRIPTION': u'Length of Responsibility for Grandchildren Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCINT': {u'BEG': 258,
#    u'DESCRIPTION': u'Interest Income in 1999',
#    u'LEN': 6,
#    u'RT': u'P'},
#   u'INCINTA': {u'BEG': 264,
#    u'DESCRIPTION': u'Interest Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCOTH': {u'BEG': 290,
#    u'DESCRIPTION': u'Other Income in 1999',
#    u'LEN': 6,
#    u'RT': u'P'},
#   u'INCOTHA': {u'BEG': 296,
#    u'DESCRIPTION': u'Other Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCPA': {u'BEG': 277,
#    u'DESCRIPTION': u'Public Assistance Income in 1999',
#    u'LEN': 5,
#    u'RT': u'P'},
#   u'INCPAA': {u'BEG': 282,
#    u'DESCRIPTION': u'Public Assistance Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCRET': {u'BEG': 283,
#    u'DESCRIPTION': u'Retirement Income in 1999',
#    u'LEN': 6,
#    u'RT': u'P'},
#   u'INCRETA': {u'BEG': 289,
#    u'DESCRIPTION': u'Retirement Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCSE': {u'BEG': 251,
#    u'DESCRIPTION': u'Self-Employment Income in 1999',
#    u'LEN': 6,
#    u'RT': u'P'},
#   u'INCSEA': {u'BEG': 257,
#    u'DESCRIPTION': u'Self-Employment Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCSS': {u'BEG': 265,
#    u'DESCRIPTION': u'Social Security Income in 1999',
#    u'LEN': 5,
#    u'RT': u'P'},
#   u'INCSSA': {u'BEG': 270,
#    u'DESCRIPTION': u'Social Security Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCSSI': {u'BEG': 271,
#    u'DESCRIPTION': u'Supplemental Security Income in 1999',
#    u'LEN': 5,
#    u'RT': u'P'},
#   u'INCSSIA': {u'BEG': 276,
#    u'DESCRIPTION': u'Supplemental Security Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCTOT': {u'BEG': 297,
#    u'DESCRIPTION': u"Person's Total Income in 1999",
#    u'LEN': 7,
#    u'RT': u'P'},
#   u'INCTOTA': {u'BEG': 304,
#    u'DESCRIPTION': u"Person's Total Income in 1999 Allocation Flag",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INCWS': {u'BEG': 244,
#    u'DESCRIPTION': u'Wage/Salary Income in 1999',
#    u'LEN': 6,
#    u'RT': u'P'},
#   u'INCWSA': {u'BEG': 250,
#    u'DESCRIPTION': u'Wage/Salary Income in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INDCEN': {u'BEG': 211,
#    u'DESCRIPTION': u'Industry (Census)',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'INDCENA': {u'BEG': 214,
#    u'DESCRIPTION': u'Industry (Census) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'INDNAICS': {u'BEG': 215,
#    u'DESCRIPTION': u'Industry (NAICS)',
#    u'LEN': 8,
#    u'RT': u'P'},
#   u'LANG1': {u'BEG': 66,
#    u'DESCRIPTION': u'Language Spoken for 1% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'LANG5': {u'BEG': 66,
#    u'DESCRIPTION': u'Language Spoken for 5% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'LANGA': {u'BEG': 69,
#    u'DESCRIPTION': u'Language Spoken Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'LASTWRK': {u'BEG': 209,
#    u'DESCRIPTION': u'Year Last Worked',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'LASTWRKA': {u'BEG': 210,
#    u'DESCRIPTION': u'Year Last Worked Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'LAYOFF': {u'BEG': 204,
#    u'DESCRIPTION': u'Layoff from Job',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'LOOKWRK': {u'BEG': 207,
#    u'DESCRIPTION': u'Looking for Work',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'LVTIME': {u'BEG': 196,
#    u'DESCRIPTION': u'Time Leaving for Work',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'LVTIMEA': {u'BEG': 199,
#    u'DESCRIPTION': u'Time Leaving for Work Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MARSTAT': {u'BEG': 44,
#    u'DESCRIPTION': u'Marital Status',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MARSTATA': {u'BEG': 45,
#    u'DESCRIPTION': u'Marital Status Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MENTAL': {u'BEG': 123,
#    u'DESCRIPTION': u'Mental Disability',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MENTALA': {u'BEG': 124,
#    u'DESCRIPTION': u'Mental Disability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MIGAREA1': {u'BEG': 101,
#    u'DESCRIPTION': u'Migration SuperPUMA Relationship to MA',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'MIGAREA5': {u'BEG': 99,
#    u'DESCRIPTION': u'Migration PUMA Relationship to MA',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'MIGCMA1': {u'BEG': 107,
#    u'DESCRIPTION': u'Migration MA: MSA/CMSA for Migration SuperPUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'MIGCMA5': {u'BEG': 103,
#    u'DESCRIPTION': u'Migration MA: MSA/CMSA for Migration PUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'MIGPMA1': {u'BEG': 115,
#    u'DESCRIPTION': u'Migration MA: MSA/PMSA for Migration SuperPUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'MIGPMA5': {u'BEG': 111,
#    u'DESCRIPTION': u'Migration MA: MSA/PMSA for Migration PUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'MIGPUMA1': {u'BEG': 94,
#    u'DESCRIPTION': u'Migration SuperPUMA',
#    u'LEN': 5,
#    u'RT': u'P'},
#   u'MIGPUMA5': {u'BEG': 89,
#    u'DESCRIPTION': u'Migration PUMA',
#    u'LEN': 5,
#    u'RT': u'P'},
#   u'MIGST1': {u'BEG': 85,
#    u'DESCRIPTION': u'Migration State or Foreign Country Code for 1% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'MIGST5': {u'BEG': 85,
#    u'DESCRIPTION': u'Migration State or Foreign Country Code for 5% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'MIGSTA': {u'BEG': 88,
#    u'DESCRIPTION': u'Migration State or Foreign County Code Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MILTARY': {u'BEG': 138,
#    u'DESCRIPTION': u'Military Service ',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MILTARYA': {u'BEG': 139,
#    u'DESCRIPTION': u'Military Service Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MILYRS': {u'BEG': 150,
#    u'DESCRIPTION': u'Years of Military Service',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MILYRSA': {u'BEG': 151,
#    u'DESCRIPTION': u'Years of Military Service Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MOB': {u'BEG': 83,
#    u'DESCRIPTION': u'Residence 5 Years Ago',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MOBA': {u'BEG': 84,
#    u'DESCRIPTION': u'Residence 5 Years Ago Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'MSP': {u'BEG': 46,
#    u'DESCRIPTION': u'Married, Spouse Present Recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'NHPI': {u'BEG': 36,
#    u'DESCRIPTION': u'Native and Other Pacific Islander recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'NUMRACE': {u'BEG': 31,
#    u'DESCRIPTION': u'Number of Major Race Groups Marked',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'OC ': {u'BEG': 20,
#    u'DESCRIPTION': u'Own Child Indicator',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'OCCCEN1': {u'BEG': 223,
#    u'DESCRIPTION': u'Occupation (Census) for 1% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'OCCCEN5': {u'BEG': 223,
#    u'DESCRIPTION': u'Occupation (Census) for 5% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'OCCCENA': {u'BEG': 226,
#    u'DESCRIPTION': u'Occupation (Census) Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'OCCSOC1': {u'BEG': 227,
#    u'DESCRIPTION': u'Occupation (SOC) for 1% file',
#    u'LEN': 7,
#    u'RT': u'P'},
#   u'OCCSOC5': {u'BEG': 227,
#    u'DESCRIPTION': u'Occupation (SOC) for 5% file',
#    u'LEN': 7,
#    u'RT': u'P'},
#   u'OTHER': {u'BEG': 37,
#    u'DESCRIPTION': u'Some other race recode',
#    u'LEN': 1,
#    u'RT': u'P '},
#   u'PAOCF': {u'BEG': 22,
#    u'DESCRIPTION': u'Presence and Age of Own Children, Females',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'PAUG': {u'BEG': 11,
#    u'DESCRIPTION': u'Augmented Person Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'PHYSCL': {u'BEG': 121,
#    u'DESCRIPTION': u'Physical Disability',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'PHYSCLA': {u'BEG': 122,
#    u'DESCRIPTION': u'Physical Disability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'PNUM': {u'BEG': 9,
#    u'DESCRIPTION': u'Person Sequence Number',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'POB1': {u'BEG': 72,
#    u'DESCRIPTION': u'Place of Birth for 1% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'POB5': {u'BEG': 72,
#    u'DESCRIPTION': u'Place of Birth for 5% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'POBA': {u'BEG': 75,
#    u'DESCRIPTION': u'Place of Birth Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'POVERTY': {u'BEG': 312,
#    u'DESCRIPTION': u"Person's Poverty Status",
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'POWAREA1': {u'BEG': 173,
#    u'DESCRIPTION': u'Place of Work SuperPUMA Relationship to MA',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'POWAREA5': {u'BEG': 171,
#    u'DESCRIPTION': u'Place of Work PUMA Relationship to MA',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'POWCMA1': {u'BEG': 179,
#    u'DESCRIPTION': u'Place of Work MA: MSA/CMSA for Place of Work SuperPUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'POWCMA5': {u'BEG': 175,
#    u'DESCRIPTION': u'Place of Work MA: MSA/CMSA for Place of Work PUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'POWPMA1': {u'BEG': 187,
#    u'DESCRIPTION': u'Place of Work MA: MSA/PMSA for Place of Work SuperPUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'POWPMA5': {u'BEG': 183,
#    u'DESCRIPTION': u'Place of Work MA: MSA/PMSA for Place of Work PUMA',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'POWPUMA1': {u'BEG': 166,
#    u'DESCRIPTION': u'Place of Work SuperPUMA',
#    u'LEN': 5,
#    u'RT': u'P'},
#   u'POWPUMA5': {u'BEG': 161,
#    u'DESCRIPTION': u'Place of Work PUMA',
#    u'LEN': 5,
#    u'RT': u'P'},
#   u'POWST1': {u'BEG': 157,
#    u'DESCRIPTION': u'Place of Work State or Foreign Country Code for 1% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'POWST5': {u'BEG': 157,
#    u'DESCRIPTION': u'Place of Work State or Foreign Country Code for 5% file',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'POWSTA': {u'BEG': 160,
#    u'DESCRIPTION': u'Place of Work State or Foreign Country Code Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'PWEIGHT': {u'BEG': 13,
#    u'DESCRIPTION': u'Person Weight',
#    u'LEN': 4,
#    u'RT': u'P '},
#   u'RACE1': {u'BEG': 38,
#    u'DESCRIPTION': u'Race Recode 1',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'RACE2': {u'BEG': 39,
#    u'DESCRIPTION': u'Race Recode 2',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'RACE3': {u'BEG': 41,
#    u'DESCRIPTION': u'Race Recode 3',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'RACEA': {u'BEG': 43,
#    u'DESCRIPTION': u'Race Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'RC': {u'BEG': 21,
#    u'DESCRIPTION': u'Related Child Indicator',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'RECALL': {u'BEG': 206,
#    u'DESCRIPTION': u'Return-to-Work Recall',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'RECTYPE': {u'BEG': 1,
#    u'DESCRIPTION': u'Record Type',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'RELATE': {u'BEG': 17,
#    u'DESCRIPTION': u'Relationship',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'RELATEA': {u'BEG': 19,
#    u'DESCRIPTION': u'Relationship Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'RSPNSBL': {u'BEG': 134,
#    u'DESCRIPTION': u'Responsible for Grandchildren',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'RSPNSBLA': {u'BEG': 135,
#    u'DESCRIPTION': u'Responsible for Grandchildren Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SENSORY': {u'BEG': 119,
#    u'DESCRIPTION': u'Sensory Disability',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SENSORYA': {u'BEG': 120,
#    u'DESCRIPTION': u'Sensory Disability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SERIALNO': {u'BEG': 2,
#    u'DESCRIPTION': u'Housing/Group Quarters (GQ) Unit Serial Number',
#    u'LEN': 7,
#    u'RT': u'P'},
#   u'SEX': {u'BEG': 23, u'DESCRIPTION': u'Sex', u'LEN': 1, u'RT': u'P'},
#   u'SEXA': {u'BEG': 24,
#    u'DESCRIPTION': u'Sex Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SFN': {u'BEG': 47,
#    u'DESCRIPTION': u'Subfamily Number for this person',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SFREL': {u'BEG': 48,
#    u'DESCRIPTION': u'Subfamily Relationship',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SLFCARE': {u'BEG': 125,
#    u'DESCRIPTION': u'Self-Care Disability',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SLFCAREA': {u'BEG': 126,
#    u'DESCRIPTION': u'Self-Care Disability Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SPEAK': {u'BEG': 64,
#    u'DESCRIPTION': u'Non-English Language',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'SPEAKA': {u'BEG': 65,
#    u'DESCRIPTION': u'Non-English Language Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'TRVMNS': {u'BEG': 191,
#    u'DESCRIPTION': u'Means of Transportation to Work',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'TRVMNSA': {u'BEG': 193,
#    u'DESCRIPTION': u'Means of Transportation to Work Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'TRVTIME': {u'BEG': 200,
#    u'DESCRIPTION': u'Travel Time to Work',
#    u'LEN': 3,
#    u'RT': u'P'},
#   u'TRVTIMEA': {u'BEG': 203,
#    u'DESCRIPTION': u'Travel Time to Work Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS1': {u'BEG': 140,
#    u'DESCRIPTION': u"Veteran's Period of Service 1:  On active duty April 1995 or later",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS2': {u'BEG': 141,
#    u'DESCRIPTION': u"Veteran's Period of Service 2:  On active duty August 1990 to March 1995 (including Persian Gulf War)",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS3': {u'BEG': 142,
#    u'DESCRIPTION': u"Veteran's Period of Service 3:  On active duty September 1980 to July 1990",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS4': {u'BEG': 143,
#    u'DESCRIPTION': u"Veteran's Period of Service 4:  On active duty May 1975 to August 1980",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS5': {u'BEG': 144,
#    u'DESCRIPTION': u"Veteran's Period of Service 5: On active duty during the Vietnam Era (August 1964 to April 1975)",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS6': {u'BEG': 145,
#    u'DESCRIPTION': u"Veteran's Period of Service 6:  On active duty February 1955 to July 1964",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS7': {u'BEG': 146,
#    u'DESCRIPTION': u"Veteran's Period of Service 7:  On active duty during the Korean War (June 1950 to January 1955)",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS8': {u'BEG': 147,
#    u'DESCRIPTION': u"Veteran's Period of Service 8:  On active duty during World War II (September 1940 to July 1947)",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPS9': {u'BEG': 148,
#    u'DESCRIPTION': u"Veteran's Period of Service 9: On active duty any other time",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPSA': {u'BEG': 149,
#    u'DESCRIPTION': u"Veteran's Period of Service Allocation Flag",
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'VPSR': {u'BEG': 152,
#    u'DESCRIPTION': u"Veteran's Period of Service Recode",
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'WEEKS': {u'BEG': 238,
#    u'DESCRIPTION': u'Weeks Worked in 1999',
#    u'LEN': 2,
#    u'RT': u'P'},
#   u'WEEKSA': {u'BEG': 240,
#    u'DESCRIPTION': u'Weeks Worked in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'WHITE': {u'BEG': 32,
#    u'DESCRIPTION': u'White recode',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'WRKLYR': {u'BEG': 236,
#    u'DESCRIPTION': u'Worked in 1999',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'WRKLYRA': {u'BEG': 237,
#    u'DESCRIPTION': u'Worked in 1999 Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'},
#   u'YR2US': {u'BEG': 78,
#    u'DESCRIPTION': u'Year of Entry to United States',
#    u'LEN': 4,
#    u'RT': u'P'},
#   u'YR2USA': {u'BEG': 82,
#    u'DESCRIPTION': u'Year of Entry to United States Allocation Flag',
#    u'LEN': 1,
#    u'RT': u'P'}}}

# %%
df1 = DataFrameWrapper(ci)
df2 = DataFrameWrapper(ci)

# %%
df1.fill_frame ([], ci.household_record,
                   five_percent_data_file,
                   ci.five_percent_file, 'TENURE', 'VALUE', 'YRBUILT', 'RENT ', 'HINC', 'SUBSAMPL', 'PUMA5')

# %%
df2.fill_frame ([], ci.person_record,
                   five_percent_data_file,
                   ci.five_percent_file, 'RACE3', 'INCTOT', 'SEX', 'age')

# %%
df1.save_frame('Alaska2000_5PUMS_Household.csv',header=True)
# df1_dict ={'serial_no':object,'PUMA':object,'AREA':object,'Tenure':object,
#               'Property Value':object,'Year Built':object,'Rent':object}

# %%
df2.save_frame('Alaska2000_5PUMS_Person.csv',header=True)
# df2_dict ={'serial_no':object,'Race':object,'Income':object,
#               'Gender':object,'Age':object}

# %%
p_df1 = pd.read_csv('Alaska2000_5PUMS_Household.csv')
p_df2 = pd.read_csv('Alaska2000_5PUMS_Person.csv')

# %%
p_df2

# %% [raw]
# # %load read_in_census_data
# """
# Three panda-related assignment ideas. All using one percent data
#
# 1) Compare Alabama and CA data. (intro to query language)
# [too vague as yet]
#
# 2)  Construct a graph examining the correlation
# of two person variables (education and income).
# Ask them to write a script making the necessary queries
# to collect data points over intervals on these
# two interval variables.
#
# 3) Create an extract in some specfic format,
# catering to particular needs.
# Use the HOUSEHOLD concept (both household and person records have a
# field for the household serial number [field SERIALNO], establishing
# a link that can be used to aggregate data about asingle household.)
# (R format: data frame)
# [The dataframe class below is an example-solution to this.  CReates
# a Python dataframe-like object from some specified
# subset of the census DB and saves it to a file
# in a format readable by R.]
#
# CREATE A DATAMODEL
# ==================
#
# Basically all the data is stored in bunch of long strings
# with the various bits of information weirdly encoded.  A data model tells
# what kind of information is available, where each kind of information
# is stored, and what the weird encodings mean.
#
# The PUMS site defines most of the important
# parts of thedata model in one big Excel sheet.
# The CensusInfo class below reads in the Excel sheet,
# stores a queryable Python version of the data madel, and
# provides read functions for reading all or part of the
# actual PUMS data (stored in big text files on the website)
# in to a usable Python data structure.
#
#         >>> ci = CensusInfo (xl_file)
#
# Converts the EXcel sheet
# into an internal Python data dictionary. Provides some
# simple data retrieval capability through C{select_rows} and some
# synonyms for important columns. Provides explanations of the
# variables and variable values through the C{var_info} method.
#
#
# Also provides some simple sata retrieval capability from
# the actual PUMS data.  But the data retrieval capability is minimal.
# Leaves the row strings that are actually
# complex DB records as strings an d does not convert them
# into any native Python structures.
#
#     Examples
#     =======
#
#     >>> ci.print_var_info('RELATE',ci.person_record,ci.one_percent_file)
#     Person Record RELATE 1% file {u'RT': u'P', u'BEG': 17, u'LEN': 2, u'DESCRIPTION': u'Relationship'}
#
#      Relationship
#      ============
#      01  Householder
#      02  Husband/wife
#      03  Natural born son/daughter
#      04  Adopted son/daughter
#      05  Stepson/Stepdaughter
#      06  Brother/sister
#      07  Father/mother
#      08  Grandchild
#      09  Parent-in-law
#      10  Son-in-law/daughter-in-law
#      11  Other relative
#      12  Brother-in-law/sister-in-law
#      13  Nephew/niece
#      14  Grandparent
#      15  Uncle/aunt
#      16  Cousin
#      17  Roomer/boarder
#      18  Housemate/roommate
#      19  Unmarried partner
#      20  Foster child
#      21  Other nonrelative
#      22  Institutionalized GQ person
#      23  Noninstitutionalized GQ person
#
#     >>> rows2 = ci.select_rows([('race','47'),('education',13,operator.gt) ], \
#         ci.person_record, five_percent_data_file, ci.five_percent_file, verbose=True)
#
#     race       eq  47  3.4684% of the Person Records
#     education  gt  13
#
#     rows2 is a list of row strings from the DB.
#
#     The intended usage is to use the dataframe class to
#     make a Python internal rep of actual parts of a
#     PUMS db.  The best way to do that is using the Panda interface.
#
#
# CREATE A DATAFRAME (R)
# =====================
# (idea from Norman Matloff's Art of R Programming)
#
# A dataframe is a matrix with labeled cols (dont
# know if rows can also be labeled; dont have to be)
#
# More specifically R vectors (1 dimension) and matrices (2 dimensions)
# have to be homogeneous (all  cells filled with entities of the same type).
# Each has
# a heterogeneous analogue: vector => list; matrix=> data frame.
#
# Python has nothing analogous.  The closest in terms of the raw data
# requirement would be a list of lists, but there is no way to cleanly
# slice out a column in a list of lists, or to carve out arbitatry
# subtables, so much of the flexibility of a dataframe is absent.  Numpy
# arrays have all this, but must store homogeneous data types (all float
# 32 or float 64 or all strings), and that is quite a limitation.
#
# Soln 1:  Use pandas (http://pandas.pydata.org/), which really has done
# a very good implementation of a dataframe.  By far the best soln
# Pandas is a big install, but it is  included in the Enthought dist of Python.
#
# Soln2  Use
# Keith Goodman's labeled array package (https://pypi.python.org/pypi/la)
# [simpler, also built on top of numpy arrays]. Labeled arrays
# are called "Larries".  They
# are implemented as instance objects with a pair of lists (labels for cols, rows)
# and a numpy array. Larries are therefore not size
# mutable and cannot store heterogenous data, like
# real R dataframes.
#
# Soln3:  Native Python solution 1. An instance object with a pair of lists (labels for cols, rows)
# and a numpy array.  Whcih is essentially whata larry is,
# and therefore suffers from the same problem.
#
# Soln4:  Native Python soln 2. A Python list of lists. with associated labelling.
# So, an instance object wrapped around a list.  No
#
# """
# #from xlIO import xlReader
#
# import xlrd,re,operator
# from collections import defaultdict, Counter
# import pandas as pd
#
# def format_list(xl_sheet,keys=['URL'], encoding=None):
#     """
#     Get the values in the first line of the excel sheet which is
#     such that all keys values are found.  A key is a col_name that must
#     be found.   We allow for ntuple keys.
#
#     This line is  assumed to  label the columns in the excel sheet (format line)
#     """
#     searching = True
#     is_empty_str = lambda x: x == ''
#     ctr = 0
#     while searching:
#         try:
#             rvs = xl_sheet.row_values(ctr)
#             searching = any((x not in rvs for x in keys))
#             #searching = not (key in rvs)
#         except IndexError:
#             print 'No format row found through row %d' % (ctr,)
#             return []
#         ctr += 1
#     if encoding:
#         return [encoding(v)[0] for v in rvs]
#     else:
#         return rvs
#
# def decompose_spec (spec):
#     """
#     For query specs used in very rudimerntary queriy language.
#
#     Conceptually a field/val/op triple, but
#     op is optional (interpreted as the default
#     op eq when absent).
#     """
#     try:
#         (field,val,op) = spec
#     except ValueError:
#         (field, val) = spec
#         op = operator.eq
#     return (field,val,op)
#
# ##############################################################################
# ##############################################################################
# ##
# ##     D a t a       C l a s s
# ##
# ##############################################################################
# ##############################################################################
#
# class CensusInfo (object):
#
#     """
#     Reads in an Excel sheet data dictionary from the Census data website
#     for PUMS data (Public Use MicroData).
#
#         >>> ci = CensusInfo (data_model_file)
#
#     Converts into an internal Python data dictionary. Provides some
#     simple data retrieval capability through C{select_rows} and some
#     synonyms for important columns. Provides explanations of the
#     variables and variable values through the C{var_info} method.
#
#     But does very litle.  Leaves the row strings that are actually
#     complex DB records as strings an d does not convert them
#     into any native Python structures.
#
#     Examples
#     =======
#
#     >>> ci.print_var_info('RELATE',ci.person_record,ci.one_percent_file)
#     Person Record RELATE 1% file {u'RT': u'P', u'BEG': 17, u'LEN': 2, u'DESCRIPTION': u'Relationship'}
#
#      Relationship
#      ============
#      01  Householder
#      02  Husband/wife
#      03  Natural born son/daughter
#      04  Adopted son/daughter
#      05  Stepson/Stepdaughter
#      06  Brother/sister
#      07  Father/mother
#      08  Grandchild
#      09  Parent-in-law
#      10  Son-in-law/daughter-in-law
#      11  Other relative
#      12  Brother-in-law/sister-in-law
#      13  Nephew/niece
#      14  Grandparent
#      15  Uncle/aunt
#      16  Cousin
#      17  Roomer/boarder
#      18  Housemate/roommate
#      19  Unmarried partner
#      20  Foster child
#      21  Other nonrelative
#      22  Institutionalized GQ person
#      23  Noninstitutionalized GQ person
#
#     >>> rows2 = ci.select_rows([('race','47'),('education',13,operator.gt) ], \
#         ci.person_record, five_percent_data_file, ci.five_percent_file, verbose=True)
#
#     race       eq  47  3.4684% of the Person Records
#     education  gt  13
#
#     rows2 is a list of row strings from the DB.
#
#     Build one of these.  Then use the dataframe class to
#     make a Python internal rep of actual parts of a
#     PUMS db.
#
#      >>> ci = CensusInfo (xl_file)
#      >>> df = DataFrame(ci)
#     >>> df.fill_frame ([], ci.person_record, one_percent_data_file, ci.one_percent_file, \
#                    'race','education','income','gender','age','relationship')
#
#     >>> one_percent_extract = os.path.join(one_percent_dir,'revisedpums1_alabama_01_race_education_income_gender_age_relationship_with_headers.dat')
#     >>> df.save_frame(one_percent_extract)
#     """
#
#     file_types = [u'5% file', u'1% file']
#     five_percent_file = file_types[0]
#     one_percent_file = file_types[1]
#     record_types = [u'Housing Unit Record', u'Person Record']
#     household_record = record_types[0]
#     person_record = record_types[1]
#     record_type_codes = [u'H', u'P']
#     record_type_dict = dict(zip(record_types,record_type_codes))
#     # where the variables names are in the excel sheet
#     # DB dictionary
#     (variable_field,variable_col) = (u'VARIABLE',5)
#     key = 'serial_no'
#
#     # Convenient field names for user.  List of important fields
#     synonyms = dict(education = 'EDUC',
#                     race = 'RACE3',
#                     nonnative_speaker = 'ENGABIL',
#                     language5 = 'LANG5', #5% file
#                     language1 = 'LANG1', #1% file
#                     citizen = 'CITIZEN',
#                     married = 'MARSTAT',
#                     income = 'INCWS',
#                     num_persons = 'PERSONS', # Num persons in household (H recs only)
#                     serial_no = 'SERIALNO', # Household serial number (links H&P records)
#                     white = 'WHITE',
#                     black = 'BLACK',
#                     asian = 'ASIAN',
#                     gender = 'SEX',
#                     age = 'AGE ',
#                     relationship = 'RELATE'
#                     )
#
#     #  Functional properties of the variable, e.g., its start end location in the record,
#     #  its explanation, one of each oer variable
#     variable_properties_list = [u'RT', u'BEG',u'LEN',u'DESCRIPTION']
#     variable_properties_cols = [0,1,3,6]
#     variable_properties_dict   = \
#           dict(zip(variable_properties_list,variable_properties_cols))
#
#     #  List or description of all the values the variable can have.
#     variable_explanation_list = [u'LO',u'HI',u'VALUE DESCRIPTION']
#     variable_explanation_cols_dict = {five_percent_file: [7,8,9],
#                                  one_percent_file: [10,11,12],
#                                  }
#
#     col_names = variable_properties_list + variable_explanation_list + [variable_field]
#
#     for file_type in variable_explanation_cols_dict.keys():
#         variable_explanation_cols_dict[file_type] = \
#                          dict(zip(variable_explanation_list,variable_explanation_cols_dict[file_type]))
#
#     def __init__ (self, data_model_file):
#         """
#         C{cata_model_file} is a census format EXcel sheet containing
#         the data model.
#         """
#
#         ## A default val
#         self.file_type = self.file_types[0]
#         xl_book = xlrd.open_workbook(data_model_file,formatting_info=True)
#         #  Functional properties of the variable, e.g., its start end location in the record,
#         #  its explanation, one of each oer variable
#         data_dictionary = dict()
#         self.data_dictionary = data_dictionary
#         #  List or description of all the values the variable can have.
#         variable_values_dictionary = dict()
#         self.variable_values_dictionary = variable_values_dictionary
#
#         for sheet_index in range(xl_book.nsheets):
#             thesheet =  xl_book.sheet_by_index(sheet_index)
#             # all_col_labels not used.  We use this as a wellformedness test
#             all_col_labels = format_list(thesheet,keys=self.col_names)
#             record_type = thesheet.name
#
#             ## Two different data universes in the two sheets
#             this_data_dict = dict()
#             self.data_dictionary[record_type] = this_data_dict
#             this_explanation_dict = dict()
#             self.variable_values_dictionary[record_type] = this_explanation_dict
#
#             print "Processing '%s' Sheet" % thesheet.name
#             print
#             # assuming this is fixed
#             #variable_col = these_cols[variable_field]
#             for row_num in range(thesheet.nrows):
#                 row = thesheet.row_values(row_num)
#                 this_var = row[self.variable_col]
#                 #print this_var
#                 if this_var == self.variable_field:
#                     continue
#                 if this_var and any((x.strip() for x in row)):
#                     #Row contains var and doesnt just consist of empties
#                     if this_var not in this_data_dict:
#                         this_variable_data_dict = dict()
#                         this_data_dict[this_var] = this_variable_data_dict
#                         for (field,col_num) in self.variable_properties_dict.iteritems():
#                             val = row[col_num]
#                             if field in ['BEG','LEN']:
#                                 try:
#                                     val = int(val)
#                                 except ValueError:
#                                     pass
#                             this_variable_data_dict[field] = val
#                     for file_type in self.file_types:
#                         these_cols = self.variable_explanation_cols_dict[file_type]
#                         if (this_var,file_type) not in this_explanation_dict:
#                             this_variable_explanation_dict = dict()
#                             this_explanation_dict[(this_var,file_type)] = this_variable_explanation_dict
#                         else:
#                             this_variable_explanation_dict = this_explanation_dict[(this_var,file_type)]
#                         (low_str, hi_str, desc) = (row[these_cols[u'LO']],row[these_cols[u'HI']],
#                                                    row[these_cols[u'VALUE DESCRIPTION']])
#                         if hi_str:
#                             this_variable_explanation_dict[(low_str,hi_str)] = desc
#                         else:
#                             this_variable_explanation_dict[low_str] = desc
#         legal_vars = set([])
#         self.legal_vars = legal_vars
#         for (rt, var_dict) in self.data_dictionary.iteritems():
#             for (var, var_info) in var_dict.iteritems():
#                 legal_vars.add((rt,var))
#
#
#     def _get_db_val_ (self, row, field, record_type):
#         """
#         row:  the row string from the DB
#         field: the field of the request, a string found in the VARIABLES
#                col in the DB dictionary
#         record_type: one of self.record_types:
#                [u'Housing Unit Record',u'Person Record']
#
#         Return None if record is not of correct type.
#         """
#         if self.check_row_record_type(record_type, row):
#             var_info = self.data_dictionary[record_type][field]
#             (start,offset) = (var_info['BEG']-1,var_info['LEN'])
#             return row[start:start+offset]
#
#     def __get_db_val__ (self, row, field, record_type):
#         """
#         row:  the row string from the DB
#         field: the field of the request, a string found in the VARIABLES col in the DB dictionary
#         record_type: one of self.record_types: [u'Housing Unit Record',u'Person Record']
#
#         Returns None if record is not of correct type.
#
#         Fastest version: Omit even row type check.  Do not use w/o
#         some kind of prior checking.
#         """
#         global var_info0, record_type0, row0, field0
#         #print 'hi'
#
#         var_info = self.data_dictionary[record_type][field]
#         (row0, var_info0,record_type0,field0) = row, var_info,record_type,field
#         #print row, field, record_type
#         (start,offset) = (var_info['BEG']-1,var_info['LEN'])
#         return row[start:start+offset]
#
#     def check_row_record_type (self, record_type, row):
#         return self.record_type_dict[record_type] == row[0]
#
#     def _cmp_db_val_ (self, row, field, record_type,query_val,op):
#         """
#         Assuming value is never None so we always return False
#         for records of wrong type.
#         """
#         db_val = self.__get_db_val__(row,field,record_type)
#         if type(query_val) == int:
#             try:
#                 db_val = int(db_val)
#             except ValueError:
#                 return False
#         return op(db_val,query_val)
#
#     def get_db_val (self, row, field, record_type):
#         """
#         row:  the row string from the DB
#         field: the field of the request, an actual value in the VARIABLES col in the DB dictionary
#         record_type: one of [u'Housing Unit Record',u'Person Record']
#
#         """
#         field = self.check_record_type_field(record_type,field)
#         return self._get_db_val_ (row, field, record_type)
#
#
#     def print_var_info (self, var0, record_type, file_type=None):
#
#         if file_type is None:
#             file_type = self.file_type
#
#         new_var0 = self.check_record_type_field(record_type,var0)
#
#         (var_info,var_values_info) = \
#                  (self.data_dictionary[record_type][new_var0],self.variable_values_dictionary[record_type][(new_var0,file_type)])
#
#         if var0 == new_var0:
#             var_str = var0
#         else:
#             var_str = '%s => %s' % (var0, new_var0)
#
#         print record_type, var_str, file_type, var_info
#         field_len = var_info['LEN']
#         print
#         print ' ' * 4, var_info['DESCRIPTION']
#         print ' ' * 4, len(var_info['DESCRIPTION']) * '='
#         var_values = sorted(var_values_info.keys())
#         for code in var_values:
#             print ' ' * 4, '%*s  %s' % (field_len, code, var_values_info[code])
#         print
#
#     def open_db_file (self, db_file, file_type):
#         assert file_type in self.file_types, '%s not one of recognized file types %s' % (file_type, self.file_types)
#         self.file_type = file_type
#         return open(db_file,'r')
#
#     def check_specs(self, specs, record_type):
#         """
#         Currently record type must be the same for all specs in a spec list,
#         since we can only check one row at a time.
#         """
#         res = []
#         for spec in specs:
#             (field,val,op) = decompose_spec(spec)
#             field = self.check_record_type_field(record_type,field)
#             assert val is not None, "Can't use None as a checkable DB value!"
#             assert not(((op == operator.gt) or (op == operator.lt)) and type(val) == str),\
#                    "Can only use inequality comparisons with numbers [not strings ('%s')]" % (val,)
#             res.append((field,val,op))
#         return res
#
#
#     def check_record_type_field(self, record_type,field):
#         assert record_type in self.record_types, '%s is not one of the known record types %s' % (record_type, self.record_types)
#         try:
#             assert (record_type,field) in self.legal_vars, '%s is not a known variable for a %s' % (field, record_type)
#         except AssertionError as e:
#             try:
#                new_field = self.synonyms[field]
#                assert (record_type,new_field) in self.legal_vars, \
#                       '%s=>%s is not a known variable for a %s' % (field, new_field, record_type)
#             except KeyError:
#                 #raise Exception, '%s is not a known variable or variable synonym for a %s' % (field, record_type)
#                 raise e
#             field = new_field
#         return field
#
#
#     def select_rows (self, specs, record_type, db_file, file_type, op=operator.eq,verbose=False):
#         """
#         Specs is a list of field, val_op pairs.  A val_op is a
#         Return a list containing each line in db file that satisfies ALL specs (conjunctive interp of specs).
#
#         Optional operator spec.  Currently same operator and same record_type applies to all specs, for simplicity.
#
#         """
#         new_specs = self.check_specs(specs,record_type)
#         row_ctr = self.reset_event_counter('rows')
#         with self.open_db_file(db_file,file_type) as fh:
#             res = []
#             for line in fh:
#                 line = line.strip()
#                 if self.check_row_record_type (record_type, line):
#                     ##  Do record check first, counting only records of right type as query rows, for
#                     ## more  sensible percentage calculations.
#                     row_ctr['rows'] += 1
#                     if all((self._cmp_db_val_ (line, field, record_type,val, op) for (field, val, op) in new_specs)):
#                         res.append(line)
#         if verbose:
#             self.print_result_summary(specs,res,record_type)
#         return res
#
#
#     def reset_event_counter (self,event_type):
#         if hasattr(self, 'event_counter'):
#             self.event_counter[event_type] = 0
#             return self.event_counter
#         else:
#             ctr = Counter()
#             self.event_counter = ctr
#             return ctr
#
#     def print_result_summary(self, specs,res,record_type):
#         spec_strs = self.__get_spec_print_strs__(specs)
#         max_width = max(map(len, spec_strs))
#         print '% *s  %.4f%% of the %ss' % (max_width, spec_strs[0], 100*(float(len(res))/self.event_counter['rows']),record_type)
#         for ss in spec_strs[1:]:
#             print '%s  ' % ss
#         print
#
#     def __get_spec_print_strs__ (self,specs):
#         specs = [decompose_spec(spec) for spec in specs]
#         fields_width = max(map(len, [ss[0] for ss in specs]))
#         ops_width = max(map(len, [ss[2].__name__ for ss in specs]))
#         vals_width = max(map(len, [str(ss[1]) for ss in specs]))
#         return ['%*s  %*s  %*s' % (fields_width, field, ops_width, op.__name__, vals_width, val) for (field, val,op) in specs]
#
#     def get_internal_field_name (self, name):
#         try:
#             return self.synonyms[name]
#         except KeyError:
#             return name
#
#
#     def get_sample_record_from_db (self,db_file):
#         print 'Opening %s' % (db_file,)
#         with open(db_file,'r') as fh:
#             line = fh.readline().strip()
#             line = fh.readline().strip()
#         print line
#         return line
#
#
# class DataFrameWrapper (object):
#     """
#     Usage conventions
#     =================
#     Uses a data model such as the
#     CensusInfo instance called C{ci} in the examples
#     below.  Then use this class to
#     make a Python internal rep of the actual parts of a PUMS DB.
#
#     >>> ci = CensusInfo (xl_file)
#     >>> df = DataFRameWrapper(ci)
#     >>> df.fill_frame ([], ci.person_record, one_percent_data_file, ci.one_percent_file, \
#                    'race','education','income','gender','age','relationship')
#
#     C{df} now contains a Python list of lists rep of the relevant info from all
#     the rows. First arg (an empty list) here, can be any list of query specs of
#     the sort used by the CensusInfo C{select_rows} method, for subsetting the
#     census DB.
#
#     Choose a filename and then save,
#
#     >>> one_percent_extract = os.path.join(one_percent_dir,'census.dat')
#     >>> df.save_frame(one_percent_extract)
#
#     The file is in a format suitable for reading into either a pandas or R dataframe.
#
#
#     With default comma separator, read this into R with the R command::
#
#      > df <- read.table('census.dat',header=TRUE,sep=",")
#      > str(df)
#      'data.frame':	44487 obs. of  7 variables:
#      $ serial_no   : int  117 117 117 127 127 127 127 134 195 195 ...
#      $ race        : int  47 47 47 47 47 47 47 47 47 47 ...
#      $ education   : int  12 12 0 5 10 5 7 13 10 9 ...
#      $ income      : int  47300 24300 NA 0 22000 0 5000 13000 0 0 ...
#      $ gender      : int  1 2 1 1 2 1 1 2 1 2 ...
#      $ age         : int  31 25 0 22 35 19 18 23 56 56 ...
#      $ relationship: int  1 2 3 1 2 5 17 1 1 2 ...
#
#
#     Read into pandas (in Python) with::
#       >>> import pandas as pd
#       >>> pd.read_csv('census.dat', header=True)
#
#     """
#
#     def __init__ (self, data_model):
#         """
#         data model is a CensusInfo inst
#         """
#
#         self.data_model = data_model
#         self.file_type = data_model.file_type
#
#     def fill_frame (self, query_specs, record_type, db_file, file_type, *col_specs):
#         col_specs = list(col_specs)
#         db_extract = self.data_model.select_rows(query_specs,record_type,db_file,file_type)
#         ## serial_no can be used to connect everything, always include
#         col_specs = self.add_key_to_col_specs(col_specs)
#         (self.header,self.col_dict,self.rows) = (col_specs,dict(),[])
#         for db_row in db_extract:
#             row = []
#             self.rows.append(row)
#             for (i,var) in enumerate(col_specs):
#                 self.col_dict[var] = i
#                 var = self.data_model.check_record_type_field(record_type,var)
#                 row.append(self.data_model.__get_db_val__(db_row,var,record_type))
#
#
#     def make_complete_frame(self,record_type, db_file, file_type):
#
#         col_names = self.data_model.data_dictionary[record_type].keys()
#         return self.fill_frame([],record_type, db_file, file_type,
#                                *col_names)
#
#
#     def add_key_to_col_specs(self,col_specs):
#         nice_key = self.data_model.key
#         key = self.data_model.synonyms[nice_key]
#
#         if (key not in col_specs) and (nice_key not in col_specs):
#             return [nice_key] + col_specs
#         else:
#             try:
#                 key_index = col_specs.index(key)
#             except ValueError:
#                 key_index = col_specs.index(nice_key)
#             return [nice_key] + \
#                    col_specs[:key_index] + \
#                    col_specs[key_index+1:]
#
#
#     def save_frame (self, filename,header=True,separator=','):
#         """
#         Writes a file in a format readable as a dataframe by R or pandas.
#
#         Read this into pandas with the command::
#
#         df = pd.read_csv(filename)
#
#         Read this into R with the command::
#         df <- read.table('census.dat',header=TRUE,sep=",")
#         """
#         if header:
#             rows = [self.header]
#             rows.extend(self.rows)
#         else:
#             rows = self.rows
#         with open(filename,'w') as ofh:
#             for row in rows:
#                 # Get rid of space padding to satisfy data size
#                 row = [e.strip() for e in row]
#                 print >> ofh, separator.join(row)
#
#     ### Panda related methods
#
#     def make_subtable (self, cols, filename=None):
#         """
#         *** Not yet implemented ***
#
#         cols is the list of cols to include in the save subtable.
#
#         cols = ['race','education','income','gender','age','relationship']
#
#         Not yet implemented (NYI)
#         """
#
#         # select out a subset of the cols
#         cols = self.add_key_to_col_specs(cols)
#         internal_cols = [self.data_model.get_internal_field_name(col) \
#                          for col in cols]
#
#         for row in self.rows:
#             # NYI
#             pass
#
#         self.header = cols
#         self.internal_cols = internal_cols
#         self.col_dict = dict(zip(cols, range(len(cols))))
#
#
#
#         return subtable
#
#
#
#     def panda_save_subtable (self, subtable, filename,
#                              header=None, index=False):
#         """
#         subtable IS a pandas data frame.  This is just a wrapper for
#         the pandas method.
#         """
#
#
#         subtable.to_csv(filename,
#                         header=header,
#                         index=index)
#
#
# if __name__ == '__main__':
#
#     import os.path
#
#
#     ###############################################################
#     ###############################################################
#     #
#     #  Files with Census DB and Census DB data model
#     #
#     ###############################################################
#     ###############################################################
#
#     working_dir = '/Users/gawron/ext/src/Rdata/USCensusData2000'
#     one_percent_dir = os.path.join(working_dir, 'pums_1percent')
#     five_percent_dir = os.path.join(working_dir, 'pums_5percent')
#     one_percent_data_file = os.path.join(one_percent_dir,'revisedpums1_alabama_01.txt')
#     five_percent_data_file = os.path.join(five_percent_dir,'revisedpums5_Alabama_01.txt')
#     data_model_file = os.path.join(five_percent_dir, '5%_PUMS_record_layout.xls')
#
#
#     ###############################################################
#     ###############################################################
#     #
#     #  Make Data model object
#     #
#     ###############################################################
#     ###############################################################
#
#     # read i Excel file with data model
#
#     ci = CensusInfo (data_model_file)
#
#     ###############################################################
#     ###############################################################
#     #
#     #  Data Model examples
#     #
#     ###############################################################
#     ###############################################################
#
#     ci.print_var_info('RELATE',ci.record_types[1],ci.file_types[1])
#
#
#     line = ci.get_sample_record_from_db (one_percent_data_file)
#
#     file_type = ci.file_types[1]
#
#     (var0,record_type, file_type) = ('RELATE',ci.record_types[1],file_type)
#     val = ci.get_db_val(line, var0, record_type)
#     var_values_info = ci.variable_values_dictionary[record_type][(var0,file_type)]
#
#     print var0,  record_type, val, var_values_info[val]
#
#     #ci.print_var_info ('EDUC', ci.person_record)
#     ci.print_var_info ('education', ci.person_record)
#     #ci.print_var_info ('RACE3', ci.person_record)
#     ci.print_var_info ('race', ci.person_record)
#     ci.print_var_info ('income', ci.person_record)
#
#     # Common to both records, links them
#
#     ci.print_var_info('serial_no',ci.household_record)
#
#     ci.print_var_info('serial_no',ci.person_record)
#
#     ci.print_var_info('num_persons',ci.household_record)
#
#     try:
#         ci.print_var_info('num_persons',ci.person_record)
#     except Exception as e:
#         print e.message
#
#     ################################################################
#     ################################################################
#     #
#     #
#     #      Making data frame (no pandas)
#     #
#     ################################################################
#     ################################################################
#
#     #df = DataFRameWrapper(ci)
#     #### Norm Matloff's example
#     #df.fill_frame ([], ci.person_record, one_percent_data_file, ci.one_percent_file, \
#     #               'race','education','income','gender','age','relationship')
#
#     ################################################################
#     ################################################################
#     #
#     #   C r e a t e d   D a t a     F i l e s
#     #
#     ################################################################
#     ################################################################
#
#     #one_percent_extract = 'revisedpums1_alabama_01_race_education_income_gender_age_relationship_with_headers.dat'
#     one_percent_subtable = 'revisedpums1_alabama_01_race_education_income_gender_age_relationship_with_headers.dat'
#     one_percent_extract = 'revisedpums1_alabama_01_complete_with_headers.dat'
#
#     ################################################################
#     ################################################################
#     #
#     #   G e t t i n g   a   C o m p l e t e    DB   E x t r a c t
#     #
#     ################################################################
#     ################################################################
#
#
#
#     #ci = CensusInfo (xl_file)
#     #df = DataFRameWrapper(ci)
#     #df.make_complete_frame(ci.person_record,one_percent_data_file,ci.one_percent_file)
#
#
#
#     ################################################################
#     ################################################################
#     #
#     #   S a v i n g
#     #
#     ################################################################
#     ################################################################
#
#     #  Save current df frame to a file, csv format.
#     #  Only needs to be done once.  From then use pd.read_csv
#     #df.save_frame(os.path.join(one_percent_dir,one_percent_extract))
#
#     ################################################################
#     ################################################################
#     #
#     #   U s i n g    P a n d a [reading in  data, making a subtable]
#     #
#     ################################################################
#     ################################################################
#
#     # Read complete person records one percent db for alabama
#     # in to a panda dataframe.
#
#     p_df = pd.read_csv(os.path.join(one_percent_dir, one_percent_extract))
#
#     # Person records for One household
#     hhld_117_person_recs = p_df[p_df['SERIALNO']==117]
